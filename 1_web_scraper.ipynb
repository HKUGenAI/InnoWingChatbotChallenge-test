# %% [markdown]
# # Part 1 Web Scraper
# In this notebook you will learn how to build a **polite recursive web crawler** using `requests` and `BeautifulSoup4`.
#
# **What you will learn**
# - How to scrape multiple related websites safely
# - How a **recursive crawler** (BFS-style) works
# - How to respect website rules (rate limiting, domain restriction)
# - How to clean HTML into readable text
# - How to save data for later use (e.g., RAG systems or chatbots)
#
# **Target websites**
# - Innovation Wing: https://innowings.engg.hku.hk/
# - InnoAcademy: https://innoacademy.engg.hku.hk/
#
# By the end you will have a JSON dataset that can be used to power AI applications!

# %% [markdown]
# ## 1.1. Introduction to Web Scraping
#
# Web scraping is the process of automatically downloading and extracting information from websites.
#
# **Why do we need a crawler?**
# Instead of scraping one page manually, a **recursive crawler** follows links and discovers new pages automatically — just like a search engine bot.
#
# **Important rules we follow**
# - Only scrape pages we are allowed to (domain restriction)
# - Be polite: wait between requests (`DELAY`)
# - Use a realistic User-Agent so servers know it’s a student project
# - Stop after a safe limit (`MAX_PAGES`)
#
# This notebook is designed for the **Chatbot Challenge** — the scraped data will become the knowledge base for an intelligent assistant.

# %% [markdown]
# ## 1.2. Install and Import Libraries
#
# We use two main libraries:
# - **`requests`** → downloads raw HTML from the internet
# - **`beautifulsoup4` (bs4)** → parses HTML and lets us extract text and links easily
#
# We also import helper modules for URL handling, JSON saving, and timing.

# %%
# !pip install bs4 requests
# Out:
# Collecting bs4
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting requests
#   Downloading requests-2.33.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.6-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jason\projects\chatbotchallenge-student\.venv\lib\site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.26 (from requests)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\jason\projects\chatbotchallenge-student\.venv\lib\site-packages (from requests) (2026.2.25)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\jason\projects\chatbotchallenge-student\.venv\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading requests-2.33.0-py3-none-any.whl (65 kB)
# Using cached charset_normalizer-3.4.6-cp314-cp314-win_amd64.whl (154 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: urllib3, soupsieve, charset_normalizer, requests, beautifulsoup4, bs4
#
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    -------------------------- ------------- 4/6 [beautifulsoup4]
#    -------------------------- ------------- 4/6 [beautifulsoup4]
#    ---------------------------------------- 6/6 [bs4]
#
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 charset_normalizer-3.4.6 requests-2.33.0 soupsieve-2.8.3 urllib3-2.6.3
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import json
import time
import os
from typing import List, Dict, Set

# %% [markdown]
# ## 1.3. Define Constraints & Configuration
#
# Before we start crawling, we need to set clear **rules** so the crawler stays safe and focused.
#
# ### Seed URLs
# These are the starting points of our crawl.
#
# ### Allowed Domains
# We **only** allow links from the two official HKU Innovation Wing domains.
# This prevents the crawler from accidentally wandering into the entire internet!
#
# ### Other Safety Settings
# - `MAX_PAGES`: stops after 150 pages (safety limit)
# - `DELAY`: waits 1 second between requests (polite crawling)
# - `HEADERS`: defines the browser type used

# %% [markdown]
# What websites to scrape from?

# %%
SEED_URLS = [
    "https://innowings.engg.hku.hk/",
    "https://innoacademy.engg.hku.hk/",
]

# %% [markdown]
# Restrict recursive crawler to websites owned by Innowing.

# %%
ALLOWED_DOMAINS = {"innowings.engg.hku.hk", "innoacademy.engg.hku.hk"}

# Check if a URL belongs to Innowing
def is_internal_link(url: str) -> bool:
    parsed = urlparse(url)
    return parsed.netloc in ALLOWED_DOMAINS or not parsed.netloc  # allow relative links

# %% [markdown]
# Other constraints

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/133.0 Safari/537.36"
}
MAX_PAGES = 150          # Safety limit - increase if needed
DELAY = 1.0              # Seconds between requests (polite enough for this small site)

# %% [markdown]
# ## 1.4. Helper Functions
#
# We create three clean, reusable functions:
#
# 1. **`is_internal_link()`** – checks whether a link belongs to our allowed domains
# 2. **`simple_clean_text()`** – removes scripts, styles, and extra whitespace (i.e. the website code that is not related to content)
# 3. **`scrape_page()`** – downloads one page and returns clean text
#
# **Note**: There was a duplicate `is_internal_link` definition earlier — we only need it once!

# %%
# Checks whether a link belongs to the allowed domains (prevents crawling unrelated websites)
def is_internal_link(url: str) -> bool:
    parsed = urlparse(url)
    return parsed.netloc in ALLOWED_DOMAINS or not parsed.netloc  # allow relative links

# Performs the most basic cleaning: removes only JavaScript and CSS, then extracts readable text while reducing extra blank lines.
def simple_clean_text(soup: BeautifulSoup) -> str:
    # Very basic cleaning - remove script/style only
    for tag in soup(["script", "style"]):
        tag.decompose()
    text = soup.get_text(separator="\n", strip=True)
    # Remove excessive blank lines
    lines = [line.strip() for line in text.splitlines() if line.strip()]
    return "\n".join(lines)

# Downloads a single page and returns a dictionary containing the URL and its cleaned text (or an error message)
def scrape_page(url: str) -> Dict[str, str]:
    try:
        resp = requests.get(url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, "html.parser")
        text = simple_clean_text(soup)
        return {"url": url, "text": text}
    except Exception as e:
        print(f"❌ Failed {url}: {e}")
        return {"url": url, "text": f"[ERROR: {e}]"}

# %% [markdown]
# ## 1.5. How the Recursive Crawler Works
#
# We use a **queue** (Breadth-First Search) to explore pages:
#
# 1. Start with the two seed URLs
# 2. Scrape the current page
# 3. Extract all links on that page
# 4. Add any new internal links to the queue
# 5. Repeat until we reach the maximum number of pages
#
# This is exactly how real web crawlers (like Googlebot) explore the web!

# %% [markdown]
# ### Perform web crawling

# %%
print("🚀 Starting crawling...\n")

visited: Set[str] = set()
queue: List[str] = SEED_URLS[:]
documents: List[Dict[str, str]] = []

while queue and len(documents) < MAX_PAGES:
    url = queue.pop(0)
    if url in visited:
        continue

    print(f"📄 [{len(documents)+1}/{MAX_PAGES}] Scraping → {url}")
    doc = scrape_page(url)
    
    if doc["text"].strip():
        documents.append(doc)
    
    visited.add(url)

    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")
        for a in soup.find_all("a", href=True):
            full_url = urljoin(url, a["href"])
            if is_internal_link(full_url) and full_url not in visited:
                queue.append(full_url)
    except:
        pass  # ignore link extraction errors

    time.sleep(DELAY)

print(f"\n✅ Crawl finished! Collected {len(documents)} pages.")
# Out:
# 🚀 Starting crawling...
#
# 📄 [1/150] Scraping → https://innowings.engg.hku.hk/
# 📄 [2/150] Scraping → https://innoacademy.engg.hku.hk/
# 📄 [3/150] Scraping → https://innowings.engg.hku.hk/#content
# 📄 [4/150] Scraping → https://innowings.engg.hku.hk/innowing1/
# 📄 [5/150] Scraping → https://innowings.engg.hku.hk/innowing-two/
# 📄 [6/150] Scraping → https://innoacademy.engg.hku.hk/#content
# 📄 [7/150] Scraping → https://innoacademy.engg.hku.hk/aboutus/
# 📄 [8/150] Scraping → https://innoacademy.engg.hku.hk/workshop/
# 📄 [9/150] Scraping → https://innoacademy.engg.hku.hk/sharing/
# 📄 [10/150] Scraping → https://innoacademy.engg.hku.hk/pitching/
# 📄 [11/150] Scraping → https://innoacademy.engg.hku.hk/sic/
# 📄 [12/150] Scraping → https://innoacademy.engg.hku.hk/studytour/
# 📄 [13/150] Scraping → https://innoacademy.engg.hku.hk/innoshow/
# 📄 [14/150] Scraping → https://innoacademy.engg.hku.hk/robotarm2026/
# 📄 [15/150] Scraping → https://innoacademy.engg.hku.hk/sharing/projects/
# 📄 [16/150] Scraping → https://innoacademy.engg.hku.hk/funding-scheme/
# 📄 [17/150] Scraping → https://innowings.engg.hku.hk/innowing1/job/
# 📄 [18/150] Scraping → https://innoacademy.engg.hku.hk/pitching_2026/
# 📄 [19/150] Scraping → https://innoacademy.engg.hku.hk/innoshow10/
# 📄 [20/150] Scraping → https://innowings.engg.hku.hk/innowing1/membership/
# 📄 [21/150] Scraping → https://innoacademy.engg.hku.hk/projects
# 📄 [22/150] Scraping → https://innoacademy.engg.hku.hk/innoshow1/
# 📄 [23/150] Scraping → https://innoacademy.engg.hku.hk/innoshow2/
# 📄 [24/150] Scraping → https://innoacademy.engg.hku.hk/innoshow3/
# 📄 [25/150] Scraping → https://innowings.engg.hku.hk/innowing1/#content
# 📄 [26/150] Scraping → https://innowings.engg.hku.hk/innowing1/contact/
# 📄 [27/150] Scraping → https://innowings.engg.hku.hk/innowing1/sig/
# 📄 [28/150] Scraping → https://innowings.engg.hku.hk/innowing1/schedule/
# 📄 [29/150] Scraping → https://innowings.engg.hku.hk/innowing1/equipment/
# 📄 [30/150] Scraping → https://innowings.engg.hku.hk/innowing1/cloudservice/
# 📄 [31/150] Scraping → https://innoacademy.engg.hku.hk
# 📄 [32/150] Scraping → https://innoacademy.engg.hku.hk/innohub/
# 📄 [33/150] Scraping → https://innowings.engg.hku.hk/?page_id=13522
# ❌ Failed https://innowings.engg.hku.hk/?page_id=13522: 404 Client Error: Not Found for url: https://innowings.engg.hku.hk/?page_id=13522
# 📄 [34/150] Scraping → https://innowings.engg.hku.hk/innowing1/#sig
# 📄 [35/150] Scraping → https://innowings.engg.hku.hk/iiis/
# 📄 [36/150] Scraping → https://innowings.engg.hku.hk/ns/
# 📄 [37/150] Scraping → https://innowings.engg.hku.hk/hkur/
# 📄 [38/150] Scraping → https://innowings.engg.hku.hk/dbf03/
# 📄 [39/150] Scraping → https://innowings.engg.hku.hk/robocon_1/
# 📄 [40/150] Scraping → https://innowings.engg.hku.hk/quantum-bit-demonstrator/
# 📄 [41/150] Scraping → https://innowings.engg.hku.hk/astar/
# 📄 [42/150] Scraping → https://innowings.engg.hku.hk/sig-health-ai-and-technology-revita/
# 📄 [43/150] Scraping → https://innowings.engg.hku.hk/matchbox/
# 📄 [44/150] Scraping → https://innowings.engg.hku.hk/apsap/
# 📄 [45/150] Scraping → https://innowings.engg.hku.hk/robomaster/
# 📄 [46/150] Scraping → https://innowings.engg.hku.hk/smart_elderly_walker/
# 📄 [47/150] Scraping → https://innowings.engg.hku.hk/uas/
# 📄 [48/150] Scraping → https://innowings.engg.hku.hk/breed/
# 📄 [49/150] Scraping → https://innowings.engg.hku.hk/innovation-wing-tutor-25-26/
# 📄 [50/150] Scraping → https://innowings.engg.hku.hk/kit/#consultation
# 📄 [51/150] Scraping → https://innowings.engg.hku.hk/past-events
# 📄 [52/150] Scraping → https://innowings.engg.hku.hk/innowing1/inlovingmemory
# 📄 [53/150] Scraping → https://innowings.engg.hku.hk/innowing-two/#content
# 📄 [54/150] Scraping → https://innowings.engg.hku.hk/innowing2/visitors/
# 📄 [55/150] Scraping → https://innowings.engg.hku.hk/innowing2/venue/
# 📄 [56/150] Scraping → https://innowings.engg.hku.hk/innowing2/techtalk/
# 📄 [57/150] Scraping → https://innowings.engg.hku.hk/innowing2/youngscholartechtalks/
# 📄 [58/150] Scraping → https://innowings.engg.hku.hk/innowing2/hkaestechtalks/
# 📄 [59/150] Scraping → https://innowings.engg.hku.hk/innowing2/edgetalk/
# 📄 [60/150] Scraping → https://innowings.engg.hku.hk/innowing2/exhibition-technologies-and-innovations/
# 📄 [61/150] Scraping → https://innowings.engg.hku.hk/innowing2/4th-innovations-for-impact/
# 📄 [62/150] Scraping → https://innowings.engg.hku.hk/innowing2/3rd-exhibition/
# 📄 [63/150] Scraping → https://innowings.engg.hku.hk/innowing2/2nd-exhibition/
# 📄 [64/150] Scraping → https://innowings.engg.hku.hk/innowing2/inaugural-exhibition/
# 📄 [65/150] Scraping → https://innowings.engg.hku.hk/innowing-two/#about
# 📄 [66/150] Scraping → https://innowings.engg.hku.hk/iw2-opening-ceremony/
# 📄 [67/150] Scraping → https://innowings.engg.hku.hk/mit/
# 📄 [68/150] Scraping → https://innowings.engg.hku.hk/legalinformation/(opens%20in%20a%20new%20tab)
# ❌ Failed https://innowings.engg.hku.hk/legalinformation/(opens%20in%20a%20new%20tab): 404 Client Error: Not Found for url: https://innowings.engg.hku.hk/legalinformation/(opens%20in%20a%20new%20tab
# 📄 [69/150] Scraping → https://innowings.engg.hku.hk/flexible-electronics/
# 📄 [70/150] Scraping → https://innowings.engg.hku.hk/trafficcontrol/
# 📄 [71/150] Scraping → https://innowings.engg.hku.hk/brain-to-neuromorphic-chips/
# 📄 [72/150] Scraping → https://innowings.engg.hku.hk/electrochemical-energy-storage/
# 📄 [73/150] Scraping → https://innowings.engg.hku.hk/water-energy-nexus/
# 📄 [74/150] Scraping → https://innowings.engg.hku.hk/ai-health/
# 📄 [75/150] Scraping → https://innowings.engg.hku.hk/bike-sharing-system/
# 📄 [76/150] Scraping → https://innowings.engg.hku.hk/nanomechanics/
# 📄 [77/150] Scraping → https://innowings.engg.hku.hk/mega-trends/
# 📄 [78/150] Scraping → https://innowings.engg.hku.hk/ai-iot-construction/
# 📄 [79/150] Scraping → https://innowings.engg.hku.hk/clinicalscreeningmonitoring/
# 📄 [80/150] Scraping → https://innowings.engg.hku.hk/rydberg-atomic-receive/
# 📄 [81/150] Scraping → https://innowings.engg.hku.hk/oeds/
# 📄 [82/150] Scraping → https://innowings.engg.hku.hk/6g-wireless-networks/
# 📄 [83/150] Scraping → https://innowings.engg.hku.hk/reinforced-concrete-structures/
# 📄 [84/150] Scraping → https://innowings.engg.hku.hk/indoor-airflow/
# 📄 [85/150] Scraping → https://innowings.engg.hku.hk/climate/
# 📄 [86/150] Scraping → https://innowings.engg.hku.hk/filter/
# 📄 [87/150] Scraping → https://innowings.engg.hku.hk/cfd-modelling/
# 📄 [88/150] Scraping → https://innowings.engg.hku.hk/bci/
# 📄 [89/150] Scraping → https://innowings.engg.hku.hk/aimodels/
# 📄 [90/150] Scraping → https://innowings.engg.hku.hk/eraofai/
# 📄 [91/150] Scraping → https://innowings.engg.hku.hk/greenhydrogen/
# 📄 [92/150] Scraping → https://innowings.engg.hku.hk/microbiology/
# 📄 [93/150] Scraping → https://innowings.engg.hku.hk/carbonneutrality/
# 📄 [94/150] Scraping → https://innowings.engg.hku.hk/grainstolandslides/
# 📄 [95/150] Scraping → https://innowings.engg.hku.hk/robotics-automation/
# 📄 [96/150] Scraping → https://innowings.engg.hku.hk/nanotechnology/
# 📄 [97/150] Scraping → https://innowings.engg.hku.hk/markets-graphs/
# 📄 [98/150] Scraping → https://innowings.engg.hku.hk/chatgpt-to-deepseek/
# 📄 [99/150] Scraping → https://innowings.engg.hku.hk/urbanwatersecurity/
# 📄 [100/150] Scraping → https://innowings.engg.hku.hk/legalinformation/
# 📄 [101/150] Scraping → https://innowings.engg.hku.hk/healthybuilding/
# 📄 [102/150] Scraping → https://innoacademy.engg.hku.hk/aboutus/#content
# 📄 [103/150] Scraping → https://innowings.engg.hku.hk/contact/
# 📄 [104/150] Scraping → mailto:innoacademy@hku.hk
# ❌ Failed mailto:innoacademy@hku.hk: No connection adapters were found for 'mailto:innoacademy@hku.hk'
# 📄 [105/150] Scraping → https://innoacademy.engg.hku.hk/workshop/#content
# 📄 [106/150] Scraping → https://innoacademy.engg.hku.hk/20260318_aiworkshop/
# 📄 [107/150] Scraping → https://innoacademy.engg.hku.hk/20260306_motioncapture/
# 📄 [108/150] Scraping → https://innoacademy.engg.hku.hk/20260204_agenticai/
# 📄 [109/150] Scraping → https://innoacademy.engg.hku.hk/20260206_droneworkshop/
# 📄 [110/150] Scraping → https://innoacademy.engg.hku.hk/20260130_iot/
# 📄 [111/150] Scraping → https://innoacademy.engg.hku.hk/pitching_2026/pitchworkshop26/
# 📄 [112/150] Scraping → https://innoacademy.engg.hku.hk/workshop/build-and-race-your-own-flipbot-challenge-re-run/
# 📄 [113/150] Scraping → https://innoacademy.engg.hku.hk/20251114_motioncapture/
# 📄 [114/150] Scraping → https://innoacademy.engg.hku.hk/20251111_nocodile/
# 📄 [115/150] Scraping → https://innoacademy.engg.hku.hk/workshop/halloween-lantern-workshop/
# 📄 [116/150] Scraping → https://innoacademy.engg.hku.hk/20251029_finetuningai/
# 📄 [117/150] Scraping → https://innoacademy.engg.hku.hk/2025_robotic_workshop_3/
# 📄 [118/150] Scraping → https://innoacademy.engg.hku.hk/workshop/build-and-race-your-own-flipbot-challenge/
# 📄 [119/150] Scraping → https://innoacademy.engg.hku.hk/2025_robotic_workshop_2/
# 📄 [120/150] Scraping → https://innoacademy.engg.hku.hk/20250922_webgpu/%20
# 📄 [121/150] Scraping → https://innoacademy.engg.hku.hk/2025_robotic_workshop_1/
# 📄 [122/150] Scraping → https://innoacademy.engg.hku.hk/20250917rag/
# 📄 [123/150] Scraping → https://innoacademy.engg.hku.hk/20250621-sua/
# 📄 [124/150] Scraping → https://innoacademy.engg.hku.hk/202504_DIY/
# 📄 [125/150] Scraping → https://innoacademy.engg.hku.hk/robotarm2025/
# 📄 [126/150] Scraping → https://innoacademy.engg.hku.hk/20250305_rag/
# 📄 [127/150] Scraping → https://innoacademy.engg.hku.hk/recruitment-talk-of-innowing-2025-summer-interns/
# 📄 [128/150] Scraping → https://innoacademy.engg.hku.hk/racingsim2025_1/
# 📄 [129/150] Scraping → https://innoacademy.engg.hku.hk/20250227_robotic/
# 📄 [130/150] Scraping → https://innoacademy.engg.hku.hk/20250228_iotworkshop/
# 📄 [131/150] Scraping → https://innoacademy.engg.hku.hk/wegoalgae02/
# 📄 [132/150] Scraping → https://innoacademy.engg.hku.hk/cad_competition-2025/
# 📄 [133/150] Scraping → https://innoacademy.engg.hku.hk/20250228_fireside/
# 📄 [134/150] Scraping → https://innoacademy.engg.hku.hk/flightsim2025a/
# 📄 [135/150] Scraping → https://innoacademy.engg.hku.hk/pitching_2025/pitchworkshop25/
# 📄 [136/150] Scraping → https://innoacademy.engg.hku.hk/racingsim2025/
# 📄 [137/150] Scraping → https://innoacademy.engg.hku.hk/dronefly/
# 📄 [138/150] Scraping → https://innoacademy.engg.hku.hk/20250122_archaeology_workshop/
# 📄 [139/150] Scraping → https://innoacademy.engg.hku.hk/20250113_CNYworkshop
# 📄 [140/150] Scraping → https://innoacademy.engg.hku.hk/20250110_firmware
# 📄 [141/150] Scraping → https://innoacademy.engg.hku.hk/20250106_ros_workshop
# 📄 [142/150] Scraping → https://innoacademy.engg.hku.hk/ros3
# 📄 [143/150] Scraping → https://innoacademy.engg.hku.hk/finetuningai/
# 📄 [144/150] Scraping → https://innoacademy.engg.hku.hk/sigrecruit24/#workshops
# 📄 [145/150] Scraping → https://innoacademy.engg.hku.hk/sigrecruit24/
# 📄 [146/150] Scraping → https://innoacademy.engg.hku.hk/igem03/
# 📄 [147/150] Scraping → https://innoacademy.engg.hku.hk/wegoalgae01/%20
# 📄 [148/150] Scraping → https://innoacademy.engg.hku.hk/matchbox01/
# 📄 [149/150] Scraping → https://innoacademy.engg.hku.hk/afirmware01/
# 📄 [150/150] Scraping → https://innoacademy.engg.hku.hk/studytour/autour24/20240726_sharing/
#
# ✅ Crawl finished! Collected 150 pages.

# %% [markdown]
# ## 1.6. Saving the Collected Data
#
# We save everything as `data.json` — a clean, machine-readable format.
#
# This file can later be loaded into a vector database for Retrieval-Augmented Generation (RAG) or a chatbot.

# %%
DATASET = os.getenv("DATASET") or "data.json"

# Save to data.json
with open(DATASET, "w", encoding="utf-8") as f:
    json.dump(documents, f, ensure_ascii=False, indent=2)

print(f"💾 Saved to {DATASET}.")
# Out:
# 💾 Saved to data.json.

# %% [markdown]
# ## 1.7. Data Quality Check (Very Important!)
#
# Now let’s inspect what we actually collected.
#
# ### Questions to ask:
# - Is the text clean and readable?
# - Are there any noisy elements (menus, footers, JavaScript leftovers)?
# - Does every page have meaningful content?
# - Are there any error messages?
#
# **Pro tip**: Always look at the first few and a few random pages before using the data!

# %%
# print first thing scraped
print(documents[0])
# Out:
# {'url': 'https://innowings.engg.hku.hk/', 'text': 'Innovation Wing\nSkip to content\nThe Tam Wing Fan Innovation Wing One\nprovides an open environment to foster\ninterdisciplinary innovations among\nundergraduate students\nand teachers in Engineering and Technology. The provision of state-of-the-art facilities in a collaborative space will enable curriculum innovations that emphasize hands-on and experiential learning activities. The Innovation Wing serves as a platform to engage the young generation to explore the world, create opportunities for them to learn about the needs of the underprivileged, and acquire practical hands-on experience in developing solutions with real-world impact.\nInnovation Wing One\nThe Tam Wing Fan Innovation Wing Two\naims to serve as an enabling platform for Engineering\nresearchers\nto interact and collaborate synergistically with researchers and professionals across various disciplines to tackle grand challenges and deliver research outputs with significant impact to Hong Kong and global communities, and at the same time to share the Faculty’s latest research achievements/findings/outputs with the large HKU and Hong Kong communities in widely accessible forms for example exhibitions and talks on research topics.\nInnovation Wing Two\nCopyright © 2026 Tam Wing Fan Innovation Wing, Faculty of Engineering, The University of Hong Kong\nFor inquiries please contact Dr. C.K. Chui (innowing[at]hku.hk), the Director of the Tam Wing Fan Innovation Wing.'}

# %% [markdown]
# 🔍 Now let's check the content scraped.<br>
# 1. Is the data quality good?<br>
# 2. Are there rubbish information (=noisy data)?<br>

# %%
print(documents[0]["text"])
# Out:
# Innovation Wing
# Skip to content
# The Tam Wing Fan Innovation Wing One
# provides an open environment to foster
# interdisciplinary innovations among
# undergraduate students
# and teachers in Engineering and Technology. The provision of state-of-the-art facilities in a collaborative space will enable curriculum innovations that emphasize hands-on and experiential learning activities. The Innovation Wing serves as a platform to engage the young generation to explore the world, create opportunities for them to learn about the needs of the underprivileged, and acquire practical hands-on experience in developing solutions with real-world impact.
# Innovation Wing One
# The Tam Wing Fan Innovation Wing Two
# aims to serve as an enabling platform for Engineering
# researchers
# to interact and collaborate synergistically with researchers and professionals across various disciplines to tackle grand challenges and deliver research outputs with significant impact to Hong Kong and global communities, and at the same time to share the Faculty’s latest research achievements/findings/outputs with the large HKU and Hong Kong communities in widely accessible forms for example exhibitions and talks on research topics.
# Innovation Wing Two
# Copyright © 2026 Tam Wing Fan Innovation Wing, Faculty of Engineering, The University of Hong Kong
# For inquiries please contact Dr. C.K. Chui (innowing[at]hku.hk), the Director of the Tam Wing Fan Innovation Wing.

# %% [markdown]
# ## 1.8. Conclusion & Next Steps
#
# **Congratulations!** 🎉
# You have successfully built a polite recursive web scraper and collected data about HKU Innovation Wing & Innovation Academy.
#
# ### What you learned
# - How to set up a controlled crawler
# - Domain restriction and politeness rules
# - HTML cleaning with BeautifulSoup
# - Saving data for AI applications
#
# ### Possible next steps
# 1. Improve text cleaning (remove non-context texts)
# 2. Use website metadata (eg. headings) to further enhance the dataset
# 3. Add data from other sources
